# %%
from pyclops.core.chemical_loss_handler import ChemicalLossHandler

loss_handler = ChemicalLossHandler.from_pdb(
    pdb_path="/Users/bendupontjr/mphil_files/all_mphil_code/pyclops/tests/peptides/pd1_binder.pdb",
    units="nm",
)
# Out:
# No residues masked from cyclization chemistry.
# /Users/bendupontjr/mphil_files/all_mphil_code/pyclops/pyclops/core/chemical_loss.py:372: UserWarning: [AmideHead2Tail] No * residues found.
#   warnings.warn(f"[{method_name}] No {'/'.join(donor_residue_names)} residues found.")
# /Users/bendupontjr/mphil_files/all_mphil_code/pyclops/pyclops/core/chemical_loss.py:372: UserWarning: [GluGlu] No GLU residues found.
#   warnings.warn(f"[{method_name}] No {'/'.join(donor_residue_names)} residues found.")
# /Users/bendupontjr/mphil_files/all_mphil_code/pyclops/pyclops/core/chemical_loss.py:372: UserWarning: [AmideOrnTail] No ORN residues found.
#   warnings.warn(f"[{method_name}] No {'/'.join(donor_residue_names)} residues found.")
# /Users/bendupontjr/mphil_files/all_mphil_code/pyclops/pyclops/core/chemical_loss.py:372: UserWarning: [GluCTerm] No GLU residues found.
#   warnings.warn(f"[{method_name}] No {'/'.join(donor_residue_names)} residues found.")
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 3
#       1 from pyclops.core.chemical_loss_handler import ChemicalLossHandler
# ----> 3 loss_handler = ChemicalLossHandler.from_pdb(
#       4     pdb_path="/Users/bendupontjr/mphil_files/all_mphil_code/pyclops/tests/peptides/pd1_binder.pdb",
#       5     units="nm",
#       6 )
#
# File ~/mphil_files/all_mphil_code/pyclops/pyclops/core/chemical_loss_handler.py:148, in ChemicalLossHandler.from_pdb(cls, pdb_path, units, units_factor, temp, alpha, mask, device, **kwargs)
#     143         raise ValueError(
#     144             f"Unknown unit: '{units}'. Valid units are: {valid_units}"
#     145         )
#     147 # Initialize the handler
# --> 148 return cls(
#     149     pdb_path=pdb_path,
#     150     units_factor=units_factor,
#     151     temp=temp,
#     152     alpha=alpha,
#     153     mask=mask,
#     154     device=device,
#     155     **kwargs
#     156 )
#
# File ~/mphil_files/all_mphil_code/pyclops/pyclops/core/chemical_loss_handler.py:205, in ChemicalLossHandler.__init__(self, pdb_path, units_factor, strategies, weights, offsets, temp, alpha, mask, device)
#     202 self._validate_mask()
#     204 # Initialize losses and build resonance groups
# --> 205 self._initialize_losses()
#
# File ~/mphil_files/all_mphil_code/pyclops/pyclops/core/chemical_loss_handler.py:358, in ChemicalLossHandler._initialize_losses(self)
#     355 resonance_key = (method_base, frozenset(idxs_method_pair.pair))
#     357 # Create loss instance
# --> 358 loss = strat(
#     359     method=idxs_method_pair.method,
#     360     atom_idxs=idxs_method_pair.indexes,
#     361     temp=self.temp,
#     362     weight=self.weights[strat],
#     363     offset=self.offsets[strat],
#     364     resonance_key=resonance_key,
#     365     device=self.device,
#     366 )
#     368 # Group by resonance key
#     369 if resonance_key not in resonance_groups:
#
# File ~/mphil_files/all_mphil_code/pyclops/pyclops/core/chemical_loss.py:146, in ChemicalLoss.__init__(self, method, atom_idxs, temp, weight, offset, resonance_key, device)
#     144 # Load KDE model using the singleton manager
#     145 kde_manager = KDEManager()
# --> 146 self.kde_pdf = kde_manager.get_kde(self.kde_file, self._device)
#     148 # Resonance tracking (used by subclasses)
#     149 self._resonance_key: Optional[Tuple[str, frozenset]] = resonance_key
#
# File ~/mphil_files/all_mphil_code/pyclops/pyclops/core/chemical_loss.py:57, in KDEManager.get_kde(self, kde_file, device)
#      55 # Load the model
#      56 logger.debug(f"Loading KDE model from file: {kde_file}")
# ---> 57 self._kde_cache[kde_file] = torch.load(kde_file, map_location=device, weights_only=False) # make more safe in future.
#      58 return self._kde_cache[kde_file]
#
# File ~/opt/anaconda3/envs/pyclops_dev/lib/python3.10/site-packages/torch/serialization.py:1026, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1024             except RuntimeError as e:
#    1025                 raise pickle.UnpicklingError(UNSAFE_MESSAGE + str(e)) from None
# -> 1026         return _load(opened_zipfile,
#    1027                      map_location,
#    1028                      pickle_module,
#    1029                      overall_storage=overall_storage,
#    1030                      **pickle_load_args)
#    1031 if mmap:
#    1032     raise RuntimeError("mmap can only be used with files saved with "
#    1033                        "`torch.save(_use_new_zipfile_serialization=True), "
#    1034                        "please torch.save your checkpoint with this option in order to use mmap.")
#
# File ~/opt/anaconda3/envs/pyclops_dev/lib/python3.10/site-packages/torch/serialization.py:1438, in _load(zip_file, map_location, pickle_module, pickle_file, overall_storage, **pickle_load_args)
#    1436 unpickler = UnpicklerWrapper(data_file, **pickle_load_args)
#    1437 unpickler.persistent_load = persistent_load
# -> 1438 result = unpickler.load()
#    1440 torch._utils._validate_loaded_sparse_tensors()
#    1441 torch._C._log_api_usage_metadata(
#    1442     "torch.load.metadata", {"serialization_id": zip_file.serialization_id()}
#    1443 )
#
# File ~/opt/anaconda3/envs/pyclops_dev/lib/python3.10/site-packages/torch/serialization.py:1431, in _load.<locals>.UnpicklerWrapper.find_class(self, mod_name, name)
#    1429         pass
#    1430 mod_name = load_module_mapping.get(mod_name, mod_name)
# -> 1431 return super().find_class(mod_name, name)
#
# ModuleNotFoundError: No module named 'pyclops.pyclops'
